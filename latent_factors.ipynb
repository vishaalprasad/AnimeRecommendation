# %% [markdown]
# This notebook expands on the simple model to predict ratings for a user, anime pair by adding in an interaction term each user and each item.
#
# rating(user, item) = offset + user_bias + item_bias + dot_product(user_latent_features, item_latent_features)
#
# When formulated this way, this is a natural extension of the linear model from the previous notebook. However, it's actually a bit deceptive what is going on with "latent_features." While a proper explanation is outside the scope of this notebook, the key here is that, as the dot_product indicates, the user and item latent feature terms are vectors.
#
# What's actually going on in this formulation is a dimensionality reduction problem. What we want to do is essentially embed each of the m users and n items (i.e. anime) in a k-dimensional space. There is no proper label for what these dimensions represent, but similar shows will group nearer to each other, and likewise for users. Since we embed them in the same space, we can take their dot product as a measure of how similar (i.e. compatible) a show and anime pair are. k itself is a hyper-parameter, though I'll begin with 2 because it's good for visualizations.
#
# Therefore, though the formulation above looks similar to the formulation of the linear model, they're actually conceptually quite difference. The objective function will be mean absolute error (MAE) with L2 regularization of all the parameters. This model is implemented in tensorflow, just for the sake of practice.
#
# Much of this code builds off of the linear model.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %matplotlib inline
matplotlib.style.use('seaborn')

# %%
from animerec.data import get_data
users, anime = get_data()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(users, test_size = 0.1) #let's split up the dataset into a train and test set.
train, valid = train_test_split(train, test_size = 0.2) #let's split up the dataset into a train and valid set.

# %%
from animerec.data import remove_users
train = remove_users(train, 10)

# %%
#define validation set
valid_users = valid['user_id']
valid_anime = valid['anime_id']
valid_ratings = valid['rating']

# %%
#initialize some local variables
nUsers = len(train.user_id.unique())
nAnime = len(train.anime_id.unique())

# we'll need some data structures in order to vectorize computations
from collections import defaultdict
user_ids = train.user_id
item_ids = train.anime_id

user_index = defaultdict(lambda: -1) # maps a user_id to the index in the bias term.
item_index = defaultdict(lambda: -1) # maps an anime_id to the index in the bias term.

counter = 0
for user in user_ids:
    if user_index[user] == -1:
        user_index[user] = counter
        counter += 1 

counter = 0
for item in item_ids:
    if item_index[item] == -1:
        item_index[item] = counter
        counter += 1

# %%
#Terms needed for the latent factors.
k = 3; # hyper-parameter

# %%
import tensorflow as tf

# %%
y = tf.cast(tf.constant(train['rating'].as_matrix(), shape=[len(train),1]), tf.float32)

# %%
def objective(alpha, Bi, Bu, Gi, Gu, y, lam): #Gi, Gu = gamma_i, gamma_u = latent factors for items, users 
    
    '''
    Like in the linear model, we need to construct the "full" matrix for each (user, item) pair. However, with the
    addition of the latent factor terms, it will wasate memory to hold each variable in its own tensor.
    Instead, create one intermediary tensor to represent our prediction ("pred") and simply incrementally add to that
    each additional variable.
    '''
    pred = tf.gather(Bi, train.anime_id.map(lambda _id: item_index[_id]).as_matrix()) #Bi_full
    pred += tf.gather(Bu, train.user_id.map(lambda _id: user_index[_id]).as_matrix()) #Bu_full
    
    Gi_full = tf.gather(Gi, train.anime_id.map(lambda _id: item_index[_id]).as_matrix()) #latent factors of items
    Gu_full = tf.gather(Gu, train.user_id.map(lambda _id: user_index[_id]).as_matrix()) #latent factors of users
    pred += tf.expand_dims(tf.einsum('ij,ji->i', Gi_full, tf.transpose(Gu_full)), 1) # dot product latent factors

    pred += tf.tile(alpha, (len(train), 1)) #alpha_full
    obj = tf.reduce_sum(abs(pred-y))


    # regularization
    obj += lam * tf.reduce_sum(Bi**2)
    obj += lam * tf.reduce_sum(Bu**2) 
    obj += lam * tf.reduce_sum(Gi**2) 
    obj += lam * tf.reduce_sum(Gu**2)
    
    return obj

# %%
#initialize alpha, Bi, Bu, Gi, Gu 
alpha = tf.Variable(tf.constant([6.9], shape=[1, 1]))
Bi = tf.Variable(tf.constant([0.0]*nAnime, shape=[nAnime, 1]))
Bu = tf.Variable(tf.constant([0.0]*nUsers, shape=[nUsers, 1]))
Gi = tf.Variable(tf.random_normal([nAnime, k], stddev=0.35))
Gu = tf.Variable(tf.random_normal([nUsers, k], stddev=0.35))

# %%
optimizer = tf.train.AdamOptimizer(0.01)

# %%
obj = objective(alpha, Bi, Bu, Gi, Gu, y, 1)

# %%
trainer = optimizer.minimize(obj)

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())
tLoss = []
vLoss = []
prev = 10e10
for iteration in range(500):
    cvalues = sess.run([trainer, obj])
    print("objective = " + str(cvalues[1]))
    tLoss.append(cvalues[1])
    
    if not iteration % 5:
        cAlpha, cBi, cBu, cGi, cGu, cLoss = sess.run([alpha, Bi, Bu, Gi, Gu, obj])
        indices = valid_users.map(lambda x: user_index[x])
        bu = indices.map(lambda x: 0.0 if x == -1 else float(cBu[x]))
        gu = indices.map(lambda x: np.zeros(k) if x == -1 else cGu[x])
        gu = np.vstack(gu.as_matrix()).astype(np.float)


        indices = valid_anime.map(lambda x: item_index[x])
        bi = indices.map(lambda x: 0.0 if x == -1 else float(cBi[x]))
        gi = indices.map(lambda x: np.zeros(k) if x == -1 else cGi[x])
        gi = np.vstack(gi.as_matrix()).astype(np.float)

        g = np.einsum('ij,ji->i', gi, np.transpose(gu)) 

        preds = bu + bi + g + float(cAlpha)
        MAE = 1.0/len(valid) * sum(abs(valid_ratings-preds))
        vLoss.append(MAE)
        if MAE > prev: break
        else: prev = MAE
    
cAlpha, cBi, cBu, cGi, cGu, cLoss = sess.run([alpha, Bi, Bu, Gi, Gu, obj])
print("\nFinal train loss is ", cLoss)
# Out:
# objective = 3.64655e+06
# objective = 3.60087e+06
# objective = 3.55697e+06
# objective = 3.51536e+06
# objective = 3.47668e+06
# objective = 3.44132e+06
# objective = 3.40894e+06
# objective = 3.37898e+06
# objective = 3.35093e+06
# objective = 3.32431e+06
# objective = 3.29878e+06
# objective = 3.27407e+06
# objective = 3.24997e+06
# objective = 3.22632e+06
# objective = 3.20299e+06
# objective = 3.17991e+06
# objective = 3.15698e+06
# objective = 3.13414e+06
# objective = 3.11133e+06
# objective = 3.08852e+06
# objective = 3.06565e+06
# objective = 3.04268e+06
# objective = 3.0196e+06
# objective = 2.99637e+06
# objective = 2.97297e+06
# objective = 2.94938e+06
# objective = 2.92562e+06
# objective = 2.90168e+06
# objective = 2.87759e+06
# objective = 2.85342e+06
# objective = 2.82924e+06
# objective = 2.80517e+06
# objective = 2.7814e+06
# objective = 2.75812e+06
# objective = 2.73558e+06
# objective = 2.714e+06
# objective = 2.69361e+06
# objective = 2.67454e+06
# objective = 2.65682e+06
# objective = 2.64037e+06
# objective = 2.62506e+06
# objective = 2.61069e+06
# objective = 2.59708e+06
# objective = 2.58401e+06
# objective = 2.57131e+06
# objective = 2.55885e+06
# objective = 2.54648e+06
# objective = 2.53417e+06
# objective = 2.52187e+06
# objective = 2.50957e+06
# objective = 2.49728e+06
# objective = 2.48503e+06
# objective = 2.47287e+06
# objective = 2.46086e+06
# objective = 2.44904e+06
# objective = 2.43744e+06
# objective = 2.42611e+06
# objective = 2.41508e+06
# objective = 2.40437e+06
# objective = 2.394e+06
# objective = 2.38398e+06
# objective = 2.37429e+06
# objective = 2.36493e+06
# objective = 2.3559e+06
# objective = 2.34718e+06
# objective = 2.33876e+06
# objective = 2.33063e+06
# objective = 2.32278e+06
# objective = 2.3152e+06
# objective = 2.30787e+06
# objective = 2.30079e+06
# objective = 2.29395e+06
# objective = 2.28732e+06
# objective = 2.28089e+06
# objective = 2.27466e+06
# objective = 2.26861e+06
# objective = 2.26273e+06
# objective = 2.25702e+06
# objective = 2.25146e+06
# objective = 2.24604e+06
# objective = 2.24075e+06
# objective = 2.23559e+06
# objective = 2.23056e+06
# objective = 2.22564e+06
# objective = 2.22084e+06
# objective = 2.21615e+06
# objective = 2.21158e+06
# objective = 2.20711e+06
# objective = 2.20276e+06
# objective = 2.19852e+06
# objective = 2.19439e+06
# objective = 2.19036e+06
# objective = 2.18642e+06
# objective = 2.18259e+06
# objective = 2.17885e+06
# objective = 2.17522e+06
# objective = 2.17167e+06
# objective = 2.16822e+06
# objective = 2.16486e+06
# objective = 2.1616e+06
# objective = 2.15842e+06
# objective = 2.15533e+06
# objective = 2.15233e+06
# objective = 2.14941e+06
# objective = 2.14657e+06
# objective = 2.14381e+06
# objective = 2.14113e+06
# objective = 2.13852e+06
# objective = 2.13599e+06
# objective = 2.13353e+06
# objective = 2.13114e+06
# objective = 2.12883e+06
# objective = 2.12658e+06
# objective = 2.12441e+06
# objective = 2.1223e+06
# objective = 2.12025e+06
# objective = 2.11827e+06
# objective = 2.11635e+06
# objective = 2.11448e+06
# objective = 2.11267e+06
# objective = 2.11091e+06
# objective = 2.10921e+06
# objective = 2.10756e+06
# objective = 2.10596e+06
# objective = 2.1044e+06
# objective = 2.10289e+06
# objective = 2.10143e+06
# objective = 2.1e+06
# objective = 2.09862e+06
# objective = 2.09728e+06
# objective = 2.09598e+06
# objective = 2.0947e+06
# objective = 2.09346e+06
# objective = 2.09225e+06
# objective = 2.09107e+06
# objective = 2.08993e+06
# objective = 2.08881e+06
# objective = 2.08772e+06
# objective = 2.08666e+06
# objective = 2.08562e+06
# objective = 2.08461e+06
# objective = 2.08363e+06
# objective = 2.08267e+06
# objective = 2.08174e+06
# objective = 2.08083e+06
# objective = 2.07993e+06
# objective = 2.07906e+06
# objective = 2.07821e+06
# objective = 2.07738e+06
# objective = 2.07656e+06
# objective = 2.07577e+06
# objective = 2.07499e+06
# objective = 2.07422e+06
# objective = 2.07348e+06
# objective = 2.07275e+06
# objective = 2.07203e+06
# objective = 2.07133e+06
# objective = 2.07064e+06
# objective = 2.06996e+06
# objective = 2.0693e+06
# objective = 2.06865e+06
# objective = 2.06801e+06
# objective = 2.06738e+06
# objective = 2.06676e+06
# objective = 2.06615e+06
# objective = 2.06555e+06
# objective = 2.06496e+06
# objective = 2.06438e+06
# objective = 2.06381e+06
# objective = 2.06325e+06
# objective = 2.0627e+06
# objective = 2.06216e+06
# objective = 2.06162e+06
# objective = 2.06109e+06
# objective = 2.06057e+06
# objective = 2.06006e+06
# objective = 2.05955e+06
# objective = 2.05905e+06
# objective = 2.05856e+06
# objective = 2.05808e+06
# objective = 2.05761e+06
# objective = 2.05713e+06
# objective = 2.05666e+06
# objective = 2.0562e+06
# objective = 2.05575e+06
# objective = 2.0553e+06
# objective = 2.05486e+06
# objective = 2.05442e+06
# objective = 2.05398e+06
# objective = 2.05355e+06
# objective = 2.05313e+06
# objective = 2.05271e+06
# objective = 2.0523e+06
# objective = 2.05189e+06
# objective = 2.05148e+06
# objective = 2.05108e+06
# objective = 2.05068e+06
# objective = 2.05029e+06
# objective = 2.0499e+06
# objective = 2.04952e+06
# objective = 2.04913e+06
# objective = 2.04876e+06
# objective = 2.04838e+06
# objective = 2.04801e+06
# objective = 2.04764e+06
# objective = 2.04728e+06
# objective = 2.04692e+06
# objective = 2.04657e+06
# objective = 2.04621e+06
# objective = 2.04586e+06
# objective = 2.04552e+06
# objective = 2.04517e+06
# objective = 2.04483e+06
# objective = 2.0445e+06
# objective = 2.04416e+06
# objective = 2.04383e+06
# objective = 2.0435e+06
# objective = 2.04318e+06
# objective = 2.04285e+06
# objective = 2.04253e+06
# objective = 2.04222e+06
# objective = 2.0419e+06
# objective = 2.04159e+06
# objective = 2.04128e+06
# objective = 2.04097e+06
# objective = 2.04067e+06
# objective = 2.04037e+06
# objective = 2.04008e+06
# objective = 2.03978e+06
# objective = 2.03949e+06
# objective = 2.03919e+06
# objective = 2.0389e+06
# objective = 2.03862e+06
# objective = 2.03833e+06
# objective = 2.03804e+06
# objective = 2.03776e+06
# objective = 2.03749e+06
# objective = 2.03721e+06
# objective = 2.03693e+06
# objective = 2.03666e+06
# objective = 2.03639e+06
# objective = 2.03612e+06
# objective = 2.03585e+06
# objective = 2.03558e+06
# objective = 2.03532e+06
# objective = 2.03506e+06
# objective = 2.0348e+06
# objective = 2.03454e+06
# objective = 2.03429e+06
# objective = 2.03403e+06
# objective = 2.03378e+06
# objective = 2.03353e+06
# objective = 2.03328e+06
# objective = 2.03303e+06
# objective = 2.03278e+06
# objective = 2.03254e+06
# objective = 2.0323e+06
# objective = 2.03206e+06
# objective = 2.03182e+06
# objective = 2.03158e+06
# objective = 2.03135e+06
# objective = 2.03111e+06
# objective = 2.03088e+06
# objective = 2.03065e+06
# objective = 2.03042e+06
# objective = 2.0302e+06
# objective = 2.02997e+06
# objective = 2.02975e+06
# objective = 2.02952e+06
# objective = 2.0293e+06
# objective = 2.02908e+06
# objective = 2.02886e+06
# objective = 2.02864e+06
# objective = 2.02842e+06
# objective = 2.02821e+06
# objective = 2.02799e+06
# objective = 2.02779e+06
# objective = 2.02758e+06
# objective = 2.02737e+06
# objective = 2.02716e+06
# objective = 2.02695e+06
# objective = 2.02674e+06
# objective = 2.02654e+06
# objective = 2.02634e+06
# objective = 2.02614e+06
# objective = 2.02594e+06
# objective = 2.02573e+06
# objective = 2.02554e+06
# objective = 2.02534e+06
# objective = 2.02514e+06
# objective = 2.02495e+06
# objective = 2.02475e+06
# objective = 2.02456e+06
# objective = 2.02437e+06
# objective = 2.02418e+06
# objective = 2.02399e+06
# objective = 2.02381e+06
# objective = 2.02362e+06
# objective = 2.02343e+06
# objective = 2.02325e+06
# objective = 2.02307e+06
# objective = 2.02289e+06
# objective = 2.02271e+06
# objective = 2.02252e+06
# objective = 2.02235e+06
# objective = 2.02217e+06
# objective = 2.02199e+06
# objective = 2.02182e+06
# objective = 2.02164e+06
# objective = 2.02147e+06
# objective = 2.0213e+06
# objective = 2.02113e+06
# objective = 2.02095e+06
# objective = 2.02078e+06
# objective = 2.02062e+06
# objective = 2.02045e+06
# objective = 2.02028e+06
# objective = 2.02012e+06
# objective = 2.01995e+06
# objective = 2.01979e+06
# objective = 2.01963e+06
# objective = 2.01947e+06
# objective = 2.0193e+06
# objective = 2.01914e+06
# objective = 2.01898e+06
# objective = 2.01882e+06
# objective = 2.01867e+06
# objective = 2.01851e+06
# objective = 2.01835e+06
# objective = 2.0182e+06
# objective = 2.01804e+06
# objective = 2.01789e+06
# objective = 2.01774e+06
# objective = 2.01758e+06
# objective = 2.01743e+06
# objective = 2.01728e+06
# objective = 2.01713e+06
# objective = 2.01698e+06
# objective = 2.01683e+06
# objective = 2.01668e+06
# objective = 2.01654e+06
# objective = 2.01639e+06
# objective = 2.01624e+06
# objective = 2.0161e+06
# objective = 2.01595e+06
# objective = 2.01581e+06
# objective = 2.01567e+06
# objective = 2.01553e+06
# objective = 2.01538e+06
# objective = 2.01524e+06
# objective = 2.01511e+06
# objective = 2.01497e+06
# objective = 2.01483e+06
# objective = 2.01469e+06
# objective = 2.01455e+06
# objective = 2.01442e+06
# objective = 2.01428e+06
# objective = 2.01414e+06
# objective = 2.01401e+06
# objective = 2.01388e+06
# objective = 2.01374e+06
# objective = 2.01361e+06
# objective = 2.01348e+06
# objective = 2.01335e+06
# objective = 2.01322e+06
# objective = 2.01308e+06
# objective = 2.01295e+06
# objective = 2.01282e+06
# objective = 2.0127e+06
# objective = 2.01257e+06
# objective = 2.01244e+06
# objective = 2.01231e+06
# objective = 2.01219e+06
# objective = 2.01206e+06
# objective = 2.01194e+06
# objective = 2.01181e+06
# objective = 2.01169e+06
# objective = 2.01157e+06
# objective = 2.01144e+06
# objective = 2.01132e+06
# objective = 2.0112e+06
# objective = 2.01108e+06
# objective = 2.01096e+06
# objective = 2.01084e+06
# objective = 2.01072e+06
# objective = 2.0106e+06
# objective = 2.01048e+06
# objective = 2.01036e+06
# objective = 2.01025e+06
# objective = 2.01013e+06
# objective = 2.01002e+06
# objective = 2.0099e+06
# objective = 2.00978e+06
# objective = 2.00967e+06
# objective = 2.00955e+06
# objective = 2.00944e+06
# objective = 2.00933e+06
# objective = 2.00921e+06
# objective = 2.0091e+06
# objective = 2.00899e+06
# objective = 2.00888e+06
# objective = 2.00877e+06
# objective = 2.00866e+06
# objective = 2.00855e+06
# objective = 2.00844e+06
# objective = 2.00833e+06
# objective = 2.00823e+06
# objective = 2.00812e+06
# objective = 2.00801e+06
# objective = 2.0079e+06
# objective = 2.0078e+06
# objective = 2.00769e+06
# objective = 2.00759e+06
# objective = 2.00748e+06
# objective = 2.00737e+06
# objective = 2.00727e+06
# objective = 2.00717e+06
# objective = 2.00707e+06
# objective = 2.00696e+06
# objective = 2.00686e+06
# objective = 2.00676e+06
# objective = 2.00666e+06
# objective = 2.00656e+06
# objective = 2.00646e+06
# objective = 2.00636e+06
# objective = 2.00625e+06
# objective = 2.00616e+06
# objective = 2.00606e+06
# objective = 2.00596e+06
# objective = 2.00586e+06
# objective = 2.00576e+06
# objective = 2.00567e+06
# objective = 2.00557e+06
# objective = 2.00547e+06
# objective = 2.00538e+06
# objective = 2.00528e+06
# objective = 2.00519e+06
# objective = 2.0051e+06
# objective = 2.005e+06
# objective = 2.00491e+06
# objective = 2.00481e+06
# objective = 2.00472e+06
# objective = 2.00463e+06
# objective = 2.00454e+06
# objective = 2.00445e+06
# objective = 2.00436e+06
# objective = 2.00427e+06
# objective = 2.00418e+06
# objective = 2.00409e+06
# objective = 2.004e+06
# objective = 2.00391e+06
# objective = 2.00382e+06
# objective = 2.00373e+06
# objective = 2.00364e+06
# objective = 2.00355e+06
# objective = 2.00347e+06
# objective = 2.00338e+06
# objective = 2.0033e+06
# objective = 2.00321e+06
# objective = 2.00312e+06
# objective = 2.00304e+06
# objective = 2.00296e+06
# objective = 2.00287e+06
# objective = 2.00279e+06
# objective = 2.0027e+06
# objective = 2.00262e+06
# objective = 2.00254e+06
# objective = 2.00245e+06
# objective = 2.00237e+06
# objective = 2.00229e+06
# objective = 2.00221e+06
# objective = 2.00213e+06
# objective = 2.00205e+06
# objective = 2.00197e+06
# objective = 2.00189e+06
# objective = 2.00181e+06
# objective = 2.00173e+06
# objective = 2.00165e+06
# objective = 2.00157e+06
# objective = 2.00149e+06
# objective = 2.00142e+06
# objective = 2.00134e+06
# objective = 2.00126e+06
# objective = 2.00118e+06
# objective = 2.00111e+06
# objective = 2.00103e+06
# objective = 2.00095e+06
# objective = 2.00088e+06
# objective = 2.00081e+06
# objective = 2.00073e+06
# objective = 2.00065e+06
# objective = 2.00058e+06
# objective = 2.00051e+06
# objective = 2.00043e+06
# objective = 2.00036e+06
# objective = 2.00028e+06
# objective = 2.00021e+06
# objective = 2.00014e+06
# objective = 2.00007e+06
# objective = 2e+06
#
# Final train loss is  1.99993e+06

# %% [markdown]
# Let's plot the objective and see how it decreases.

# %%
fig, ax1 = plt.subplots()
plt.title('Linear model performance vs. iterations')
ax1.plot(tLoss, 'b-')
ax1.set_xlabel('Training Iterations')
ax1.set_ylabel('Train Loss')

ax2 = ax1.twinx()
ax2.plot(range(0, len(vLoss)*5, 5), vLoss, 'r.')
ax2.set_ylabel('Validation Classification MAE')

fig.tight_layout()

# %% [markdown]
# We can see quite clearly that this model does not overfit, just like the linear model. L2 regularization looks to be more than enough. However, we also can see that after about 150 iterations, validation MAE mostly flatlines, which suggests a place for early stopping.
#
# Let's test the model on our test data now.

# %%
test_users = test['user_id']
test_anime = test['anime_id']
test_ratings = test['rating']

# %%
indices = test_users.map(lambda x: user_index[x])
bu = indices.map(lambda x: 0.0 if x == -1 else float(cBu[x]))
gu = indices.map(lambda x: np.zeros(k) if x == -1 else cGu[x])
gu = np.vstack(gu.as_matrix()).astype(np.float)

indices = test_anime.map(lambda x: item_index[x])
bi = indices.map(lambda x: 0.0 if x == -1 else float(cBi[x]))
gi = indices.map(lambda x: np.zeros(k) if x == -1 else cGi[x])
gi= np.vstack(gi.as_matrix()).astype(np.float)

g = np.einsum('ij,ji->i', gi, np.transpose(gu)) 

preds = bu + bi + g + float(cAlpha)
MAE = 1.0/len(test) * sum(abs(test_ratings-preds))
print ('MAE on test set is: ', float(MAE))
# Out:
# MAE on test set is:  0.885571453178356

# %%
sess.close()

# %% [markdown]
# So, an improvement over the linear model, though not by much. But the important thing is that we are now actually running a recommender system. The linear model would recommend the same shows to everyone, but now we have a legitimate interaction between users and items.
#
# We could likely improve on this by tuning our hyperparameters.
